# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "benny michel"
reason = "I am interested in AI, Data Analytics, and Data Science because I want to learn how to use data and machine learning \n to solve  problems,  making smarter decisions, and creating useful AI applications."
fun_fact = "I love playing basketball and bass, and I enjoy experimenting with side projects in Python to explore new ideas."


print(f"Hi! My name is {name}.\n I’m excited to learn because {reason}.\n A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is benny michel.
#  I’m excited to learn because I am interested in AI, Data Analytics, and Data Science because I want to learn how to use data and machine learning
#  to solve  problems,  making smarter decisions, and creating useful AI applications..
#  A fun fact about me is: I love playing basketball and bass, and I enjoy experimenting with side projects in Python to explore new ideas..
